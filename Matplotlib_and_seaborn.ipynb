# %% [markdown]
# <a href="https://colab.research.google.com/github/Bharadwaj0906/Matplotlib-and-seaborn-/blob/main/Matplotlib_and_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#to show graphs down of cells because sometimes we will get as pop ups
# %matplotlib inline

# %%
yield_apples=[0.5,0.6,0.7,0.8,0.1,1]

# %%
plt.plot(yield_apples);

# %%
# with semicolon we can see graph but not output
plt.plot(yield_apples);

# %%
years=[2010,2011,2012,2013,2014,2015]
plt.plot(years,yield_apples);

# %%
plt.plot(years,yield_apples);
plt.xlabel('Years')
plt.ylabel('Yield (tons per hectare)');

# %%
years=range(2000,2006)
apples=[0.5,0.6,0.7,0.8,0.1,1]
oranges=[0.88,0.99,0.3,0.2,1,5]
plt.plot(years,apples);
plt.plot(years,oranges);

plt.xlabel('Years')
plt.ylabel('Yield (tons per hectare)');

# %%
years=range(2000,2006)
apples=[0.5,0.6,0.7,0.8,0.1,1]
oranges=[0.88,0.99,0.3,0.2,1,5]
plt.plot(years,apples);
plt.plot(years,oranges);

plt.xlabel('Years')
plt.ylabel('Yield (tons per hectare)');
plt.title('Crop of yield in India')
# for know which colour plot is for which fruit
plt.legend(['Apples','Oranges']);

# %%
plt.plot(years,apples,marker="o");
plt.plot(years,oranges,marker="x");

plt.xlabel('Years')
plt.ylabel('Yield (tons per hectare)');
plt.title('Crop of yield in India')
# for know which colour plot is for which fruit
plt.legend(['Apples','Oranges']);

# %% [markdown]
# # Styling lines and markers
#
# The plt.plot function supports many arguments for styling lines and markers:<br>
# color or c: set the color of the line (supported colors)<br>
# linestyle or ls: choose between a solid or dashed line<br>
# linewidth or lw: set the width of a line<br>
# markersize or ms: set the size of markers<br>
# markeredgecolor or mec: set the edge color for markers<br>
# markeredgewidth or mew: set the edge width for marker <br>
# markerfacecolor or mfc : set the fill color for markers<br>
# alpha : opacity of the plot

# %%
plt.plot(years,apples,marker="o",c='b',ls='--',lw=3,ms=6,mew=5,mec='navy');
plt.plot(years,oranges,marker="x",c='r',ls='-',lw=6,ms=6,mew=3,mec='black',alpha=.5);

plt.xlabel('Years')
plt.ylabel('Yield (tons per hectare)');
plt.title('Crop of yield in India')
# for know which colour plot is for which fruit
plt.legend(['Apples','Oranges']);

# %%
#using fmt dirctlywe can write s-r
plt.plot(years,apples,'s-b');
plt.plot(years,oranges,'x--r');

plt.xlabel('Years')
plt.ylabel('Yield (tons per hectare)');
plt.title('Crop of yield in India')
# for know which colour plot is for which fruit
plt.legend(['Apples','Oranges']);

# %%
plt.plot(years,apples,"or");
plt.plot(years,oranges,'xb');

plt.xlabel('Years')
plt.ylabel('Yield (tons per hectare)');
plt.title('Crop of yield in India')
# for know which colour plot is for which fruit
plt.legend(['Apples','Oranges']);

# %%
plt.figure(figsize=(2,2));
plt.figure(figsize=(2,2));plt.plot(years,apples,marker="o");
plt.plot(years,oranges,marker="x");

plt.xlabel('Years')
plt.ylabel('Yield (tons per hectare)');
plt.title('Crop of yield in India')
# for know which colour plot is for which fruit
plt.legend(['Apples','Oranges']);

# %%
sns.set_style("whitegrid")

# %%
plt.plot(years,apples,'s-b');
plt.plot(years,oranges,'x--r');

plt.xlabel('Years')
plt.ylabel('Yield (tons per hectare)');
plt.title('Crop of yield in India')
# for know which colour plot is for which fruit
plt.legend(['Apples','Oranges']);

# %%
sns.set_style("darkgrid")

# %%
plt.plot(years,apples,'s-b');
plt.plot(years,oranges,'x--r');

plt.xlabel('Years')
plt.ylabel('Yield (tons per hectare)');
plt.title('Crop of yield in India')
# for know which colour plot is for which fruit
plt.legend(['Apples','Oranges']);

# %%
import matplotlib

# %%
matplotlib.rcParams
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.avconv_args': [],
#           'animation.avconv_path': 'avconv',
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.html_args': [],
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': True,
#           'axes.edgecolor': 'white',
#           'axes.facecolor': '#EAEAF2',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
# ...

# %%
matplotlib.rcParams['font.size']=14

matplotlib.rcParams['figure.figsize']=(9,5)
matplotlib.rcParams['figure.facecolor']= '#00000000'

# %%
plt.plot(years,apples,'s-b');
plt.plot(years,oranges,'x--r');

plt.xlabel('Years')
plt.ylabel('Yield (tons per hectare)');
plt.title('Crop of yield in India')
# for know which colour plot is for which fruit
plt.legend(['Apples','Oranges']);

# %%
# we can directly get data set from seaborn library without downloading
df1=sns.load_dataset("iris")

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.plot(df1.sepal_length,df1.sepal_width);

# %%
sns.scatterplot(df1.sepal_length,df1.sepal_width);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(df1.sepal_length,df1.sepal_width,hue=df1.species,s=100);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(12,6))
plt.title("Sepal Dimenison")
sns.scatterplot(df1.sepal_length,df1.sepal_width,hue=df1.species,s=100);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df1.sepal_width
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
plt.title("Distribution of sepal width")
plt.hist(df1.sepal_width);

# %%
plt.hist(df1.sepal_width,bins=3);

# %%
import numpy as np
np.arange(2, 5, 0.25)
# Out:
# array([2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 ,
#        4.75])

# %%
plt.hist(df1.sepal_width,bins=np.arange(2, 5, 0.25));

# %%
setosa=df1[df1.species=='setosa']
versicolor=df1[df1.species=='versicolor']
virginica=df1[df1.species=='virginica']

# %%
plt.hist(setosa.sepal_width,alpha=0.9,bins=4,color="pink")
plt.hist(versicolor.sepal_width,alpha=0.9,bins=4,color="silver")
plt.hist(virginica.sepal_width,alpha=0.9,bins=4,color="grey")
plt.legend(["setosa","versicolor","virginica"]);

# %%
plt.hist([setosa.sepal_width,versicolor.sepal_width,virginica.sepal_width],bins=4,color=("pink","silver","grey"),stacked=True)
plt.legend(["setosa","versicolor","virginica"]);

# %%
years=range(2000,2006)
apples=[0.5,0.6,0.7,0.8,0.1,1]
oranges=[0.88,0.99,0.3,0.2,1,5]

# %%
plt.bar(years,oranges);

# %%
plt.bar(years,oranges);
plt.plot(years,oranges,"o--r");

# %%
plt.bar(years,apples);
plt.bar(years,oranges,bottom=apples);

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
billavg_df=tips.groupby("day")[["total_bill"]].mean()
billavg_df
# Out:
#       total_bill
# day
# Thur   17.682742
# Fri    17.151579
# Sat    20.441379
# Sun    21.410000

# %%
plt.bar(billavg_df.index,billavg_df.total_bill)
# Out:
# <BarContainer object of 4 artists>

# %%
sns.barplot("day","total_bill",data=tips);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot("day","total_bill",hue="sex",data=tips)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot("day","total_bill",hue="smoker",data=tips)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot("total_bill","day",hue="smoker",data=tips)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df=sns.load_dataset("flights")
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
plt.plot(df.passengers)

# %%
df=sns.load_dataset("flights").pivot("month","year","passengers")

# %%
df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(df)

# %%
sns.heatmap(df,fmt="d",annot=True,cmap="Blues")

# %%
plt.subplots(2,3);

# %%
plt.subplots(2,3);
plt.tight_layout(pad=2)

# %%
fig, axes=plt.subplots(2,3,figsize=(12,9));
axes[0,0].plot(years,oranges,"o--r")
axes[0,0].plot(years,apples,"x--b")
axes[0,0].set_xlabel("Years")
axes[0,0].set_ylabel('yield (tons per heactre)')
axes[0,0].set_title("crop of yields")
axes[0,0].legend( ["oranges","Apples"])
plt.tight_layout(pad=2)

# %%
fig, axes=plt.subplots(2,3,figsize=(12,9));
axes[0,0].plot(years,oranges,"o--r")
axes[0,0].plot(years,apples,"x--b")
axes[0,0].set_xlabel("Years")
axes[0,0].set_ylabel('yield (tons per heactre)')
axes[0,0].set_title("crop of yields")
axes[0,0].legend( ["oranges","Apples"])
plt.tight_layout(pad=2)
axes[0,1].set_title("sepal length vs. width")
sns.scatterplot(df1.sepal_length,df1.sepal_width,hue=df1.species,s=100,ax=axes[0,1]);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.distplot(df1.sepal_width)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
